# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\swetha.b\\Documents\\CAR DHEKO\\car data.csv")

# %%
df.head(3)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
print(df['Seller_Type'].unique())
# Out:
# ['Dealer' 'Individual']

# %%
print(df['Transmission'].unique())
# Out:
# ['Manual' 'Automatic']

# %%
print(df['Owner'].unique())
# Out:
# [0 1 3]

# %%
##check missiing values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_dataset=df[[ 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_dataset.head(3)
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0

# %%
final_dataset['Current_Year']=2022
final_dataset.head(2)
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
#
#   Transmission  Owner  Current_Year
# 0       Manual      0          2022
# 1       Manual      0          2022

# %%
final_dataset['no_of_years']=final_dataset['Current_Year']-final_dataset['Year']

# %%
final_dataset.drop(['Year'],axis=1,inplace=True)

# %%
final_dataset.head(2)
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  no_of_years
# 0       Manual      0          2022            8
# 1       Manual      0          2022            9

# %%
final_dataset=pd.get_dummies(final_dataset,drop_first=True)

# %%
final_dataset.head(3)
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Current_Year  no_of_years  \
# 0           3.35           5.59       27000      0          2022            8
# 1           4.75           9.54       43000      0          2022            9
# 2           7.25           9.85        6900      0          2022            5
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# Current_Year                      NaN            NaN         NaN       NaN
# no_of_years                 -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         Current_Year  no_of_years  Fuel_Type_Diesel  \
# Selling_Price                    NaN    -0.236141          0.552339
# Present_Price                    NaN     0.047584          0.473306
# Kms_Driven                       NaN     0.524342          0.172515
# Owner                            NaN     0.182104         -0.053469
# Current_Year                     NaN          NaN               NaN
# no_of_years                      NaN     1.000000         -0.064315
# Fuel_Type_Diesel                 NaN    -0.064315          1.000000
# Fuel_Type_Petrol                 NaN     0.059959         -0.979648
# Seller_Type_Individual           NaN     0.039896         -0.350467
# Transmission_Manual              NaN    -0.000394         -0.098643
#
#                         Fuel_Type_Petrol  Seller_Type_Individual  \
# Selling_Price                  -0.540571               -0.550724
# Present_Price                  -0.465244               -0.512030
# Kms_Driven                     -0.172874               -0.101419
# Owner                           0.055687                0.124269
# Current_Year                         NaN                     NaN
# no_of_years                     0.059959                0.039896
# Fuel_Type_Diesel               -0.979648               -0.350467
# Fuel_Type_Petrol                1.000000                0.358321
# Seller_Type_Individual          0.358321                1.000000
# Transmission_Manual             0.091013                0.063240
#
#                         Transmission_Manual
# Selling_Price                     -0.367128
# Present_Price                     -0.348715
# Kms_Driven                        -0.162510
# Owner                             -0.050316
# Current_Year                            NaN
# no_of_years                       -0.000394
# Fuel_Type_Diesel                  -0.098643
# Fuel_Type_Petrol                   0.091013
# Seller_Type_Individual             0.063240
# Transmission_Manual                1.000000

# %%
import seaborn as sns

# %%
sns.pairplot(final_dataset)

# %%
sns.heatmap(final_dataset)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
corrmat=final_dataset.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(10,10))
g=sns.heatmap(final_dataset[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
final_dataset.head(2)
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Current_Year  no_of_years  \
# 0           3.35           5.59       27000      0          2022            8
# 1           4.75           9.54       43000      0          2022            9
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1

# %%
#independent and dependent features
x=final_dataset.iloc[:,1:]
y=final_dataset.iloc[:,0]

# %%
x.head()
# Out:
#    Present_Price  Kms_Driven  Owner  Current_Year  no_of_years  \
# 0           5.59       27000      0          2022            8
# 1           9.54       43000      0          2022            9
# 2           9.85        6900      0          2022            5
# 3           4.15        5200      0          2022           11
# 4           6.87       42450      0          2022            8
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
## feature importance 
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.37095386 0.03910459 0.00087571 0.         0.07527263 0.22846422
#  0.01109707 0.12850295 0.14572897]

# %%
feat_importance=pd.Series(model.feature_importances_,index=x.columns)
feat_importance.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (240, 9)

# %%
x_test.shape
# Out:
# (61, 9)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random=RandomForestRegressor()

# %%
#hyperparameters
import numpy as np
#randomized search cv
#no of trees in random forest
n_estimators=[int(x) for x in np.linspace(start = 100,stop=1200,num=12)]
#no of features to consider at every split
max_features=["auto","sqrt"]
#max no of levels in tree
max_depth=[int(x) for x in np.linspace(5,30,num=6)]
#max_depth.append(None)
#min number of samles required to split a node
min_samples_split=[2,5,10,15,100]
#min number of samples required to split a leaf node
min_samples_leaf=[1,2,5,10]

# %%
from sklearn.model_selection import RandomizedSearchCV
#randomgrid
random_grid={'n_estimators':n_estimators,
              'max_features':max_features,
              'min_samples_leaf':min_samples_leaf,
              'min_samples_split':min_samples_split}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'min_samples_leaf': [1, 2, 5, 10], 'min_samples_split': [2, 5, 10, 15, 100]}

# %%
rf=RandomForestRegressor()
rf_random=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,scoring='neg_mean_squared_error',n_iter=10,cv=5,random_state=42,n_jobs=1)

# %%
rf_random.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=42, scoring='neg_mean_squared_error')

# %%
prediction=rf_random.predict(x_test)
prediction
# Out:
# array([ 0.45790281,  4.66972212,  3.49802956, 22.94019084,  0.43632373,
#         9.36847383,  2.97219989,  2.67156273, 21.36607275,  4.35616536,
#         7.96658021,  5.22979792,  2.77832153,  0.42567364,  0.61416681,
#         7.03622546,  4.45135784,  5.73527927,  0.32717028,  6.83013243,
#         9.92001667,  4.25411263,  2.97219989,  0.46117772,  3.01545768,
#         2.40545941,  8.20239667,  3.18265907,  4.40909956,  3.14998421,
#         2.75598135,  5.74370214,  2.73599234, 10.02493312,  0.59014373,
#         4.77921739,  3.46327639,  0.31439165,  0.3983955 ,  0.84265878,
#        10.20593145,  0.47011038,  0.4845671 ,  6.89147852,  0.61135871,
#         8.84796611,  1.06590504,  2.44428217,  0.55674651,  6.75954437,
#         4.3377252 ,  4.07012857,  0.31553607,  0.25966508, 13.4594073 ,
#         8.24402575,  0.35896552,  6.77389981,  1.06968343,  8.9804635 ,
#         6.43256989])

# %%
sns.distplot(y_test-prediction)
# Out:
# C:\Users\swetha.b\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(y_test,prediction)

# %%
import pickle
file=open('random_forest_regression_model.pkl','wb')
#dump information to that file
pickle.dump(rf_random,file)
